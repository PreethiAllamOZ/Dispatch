# %%
import warnings
warnings.filterwarnings("ignore")

# import key libraries

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# link to image output directory

data=(r"C:\Users\pallam\Documents\GitHub\Dispatch\DD21DOR001.xlsx")
data=pd.read_excel(data, dtype=object, skiprows=2)

data=data[['Sample ID','Depth From','Depth To','Interval length','Sample Type','Standard Type','Core Type','Initials','SG Required']]
data['Prospect']= 'TURW'
data['Hole_ID']='DD21DOR001'
data['Priority']='1'
data=data.rename(columns={'Sample ID':'Sample_ID'})
data=data.rename(columns={'Depth From':'Depth_From'})
data=data.rename(columns={'Depth To':'Depth_To'})
data=data.rename(columns={'Interval length':'Sample_length'})
data=data.rename(columns={'Sample Type':'Sample_Group'})
data=data.rename(columns={'Standard Type':'Standard_ID'})
data=data.rename(columns={'Core Type':'Sample_Type'})
data=data[['Prospect','Hole_ID','Sample_ID', 'Depth_From', 'Depth_To','Sample_length','Sample_Group', 'Standard_ID', 'Sample_Type','Initials', 'Priority']]
data["Sample_Type"]=data["Sample_Type"].replace({"Half": "CORE-50", "Quarter": "CORE-25"})
data
# Out:
#     Prospect     Hole_ID Sample_ID Depth_From Depth_To Sample_length  \
# 0       TURW  DD21DOR001  D2003818        NaN      NaN           NaN
# 1       TURW  DD21DOR001  D2003819      200.5      202           1.5
# 2       TURW  DD21DOR001  D2003820        NaN      NaN           NaN
# 3       TURW  DD21DOR001  D2003821        202      204             2
# 4       TURW  DD21DOR001  D2003822        204      206             2
# 5       TURW  DD21DOR001  D2003823        206      208             2
# 6       TURW  DD21DOR001  D2003824        208      210             2
# 7       TURW  DD21DOR001  D2003825        210      212             2
# 8       TURW  DD21DOR001  D2003826        212      214             2
# 9       TURW  DD21DOR001  D2003827        214      216             2
# 10      TURW  DD21DOR001  D2003828        216      218             2
# 11      TURW  DD21DOR001  D2003829        218      220             2
# 12      TURW  DD21DOR001  D2003830        220      222             2
# 13      TURW  DD21DOR001  D2003831        222      224             2
# 14      TURW  DD21DOR001  D2003832        224      226             2
# 15      TURW  DD21DOR001  D2003833        226      228             2
# 16      TURW  DD21DOR001  D2003834        228      230             2
# 17      TURW  DD21DOR001  D2003835        230      232             2
# 18      TURW  DD21DOR001  D2003836        232      234             2
# 19      TURW  DD21DOR001  D2003837        234      235             1
# 20      TURW  DD21DOR001  D2003838        235    236.9           1.9
# 21      TURW  DD21DOR001  D2003839      236.9    238.2           1.3
# 22      TURW  DD21DOR001  D2003840        NaN      NaN             0
# 23      TURW  DD21DOR001  D2003841      238.2      240           1.8
# 24      TURW  DD21DOR001  D2003842      238.2      240           1.8
# 25      TURW  DD21DOR001  D2003843        240      242             2
# 26      TURW  DD21DOR001  D2003844        242      244             2
# 27      TURW  DD21DOR001  D2003845        244      246             2
# 28      TURW  DD21DOR001  D2003846        246      248             2
# 29      TURW  DD21DOR001  D2003847        248      250             2
# 30      TURW  DD21DOR001  D2003848        250      252             2
# 31      TURW  DD21DOR001  D2003849        252      254             2
# 32      TURW  DD21DOR001  D2003850        254      256             2
# 33      TURW  DD21DOR001  D2003851        256      258             2
# 34      TURW  DD21DOR001  D2003852        258      260             2
# 35      TURW  DD21DOR001  D2003853        260      262             2
# 36      TURW  DD21DOR001  D2003854        262      264             2
# 37      TURW  DD21DOR001  D2003855        264      266             2
# 38      TURW  DD21DOR001  D2003856        266      268             2
# 39      TURW  DD21DOR001  D2003857        268      270             2
# 40      TURW  DD21DOR001  D2003858        270    272.6           2.6
# 41      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 42      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 43      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 44      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 45      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 46      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 47      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 48      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 49      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 50      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 51      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 52      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 53      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 54      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 55      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 56      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 57      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 58      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 59      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 60      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 61      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 62      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 63      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 64      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 65      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 66      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 67      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 68      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 69      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 70      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 71      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 72      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 73      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 74      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 75      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 76      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 77      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 78      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 79      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 80      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 81      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 82      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 83      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 84      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 85      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 86      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 87      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 88      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 89      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 90      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 91      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 92      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 93      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 94      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 95      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 96      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 97      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 98      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 99      TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 100     TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 101     TURW  DD21DOR001       NaN        NaN      NaN           NaN
# 102     TURW  DD21DOR001       NaN        NaN      NaN           NaN
#
#     Sample_Group Standard_ID Sample_Type Initials Priority
# 0            REF  BLANK-CARQ   INSERT QC       DT        1
# 1          ALPHA         NaN     CORE-50       DT        1
# 2            REF     PH-UG21   INSERT QC       DT        1
# 3          ALPHA         NaN     CORE-25       DT        1
# 4          ALPHA         NaN     CORE-25       DT        1
# 5          ALPHA         NaN     CORE-25       DT        1
# 6          ALPHA         NaN     CORE-25       DT        1
# 7          ALPHA         NaN     CORE-25       DT        1
# 8          ALPHA         NaN     CORE-25       DT        1
# 9          ALPHA         NaN     CORE-25       DT        1
# 10         ALPHA         NaN     CORE-25       DT        1
# 11         ALPHA         NaN     CORE-25       DT        1
# 12         ALPHA         NaN     CORE-25       DT        1
# 13         ALPHA         NaN     CORE-25       DT        1
# 14         ALPHA         NaN     CORE-25       DT        1
# 15         ALPHA         NaN     CORE-25       DT        1
# 16         ALPHA         NaN     CORE-25       DT        1
# 17         ALPHA         NaN     CORE-25       DT        1
# 18         ALPHA         NaN     CORE-25       DT        1
# 19         ALPHA         NaN     CORE-50       DT        1
# 20         ALPHA         NaN     CORE-25       DT        1
# 21         ALPHA         NaN     CORE-50       DT        1
# 22           REF  BLANK-CARQ   INSERT QC       DT        1
# 23           DUP         NaN     CORE-50       DT        1
# 24           DUP     LAB DUP     CORE-50       DT        1
# 25         ALPHA         NaN     CORE-25       DT        1
# 26         ALPHA         NaN     CORE-25       DT        1
# 27         ALPHA         NaN     CORE-25       DT        1
# 28         ALPHA         NaN     CORE-25       DT        1
# 29         ALPHA         NaN     CORE-25       DT        1
# 30         ALPHA         NaN     CORE-25       DT        1
# 31         ALPHA         NaN     CORE-25       DT        1
# 32         ALPHA         NaN     CORE-25       DT        1
# 33         ALPHA         NaN     CORE-25       DT        1
# 34         ALPHA         NaN     CORE-25       DT        1
# 35         ALPHA         NaN     CORE-25       DT        1
